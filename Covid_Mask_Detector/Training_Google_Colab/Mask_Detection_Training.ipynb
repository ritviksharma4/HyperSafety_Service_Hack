# %%
# !git clone https://github.com/JadHADDAD92/covid-mask-detector.git
# Out:
# Cloning into 'covid-mask-detector'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 188 (delta 24), reused 28 (delta 11), pack-reused 127
# Receiving objects: 100% (188/188), 24.65 MiB | 6.99 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
# !pip install pytorch-lightning==1.2.10
# !pip install TorchMetrics
# Out:
# ...
#      |████████████████████████████████| 841 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 269 kB 52.2 MB/s
# ...
#      |████████████████████████████████| 176 kB 54.9 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 59.5 MB/s
# ...
#      |████████████████████████████████| 142 kB 67.1 MB/s
# ...
#      |████████████████████████████████| 294 kB 73.8 MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44635 sha256=a1308f208f764ab3359b13037613f6c7de5c98f5c0b84aadd3fe9d32acc78e5d
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# ...
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 0.5.0
#     Uninstalling torchmetrics-0.5.0:
#       Successfully uninstalled torchmetrics-0.5.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
# ...

# %%
import pytorch_lightning as pl
print(pl.__version__)
# Out:
# 1.2.10

# %%
# %cd covid-mask-detector
# Out:
# /content/covid-mask-detector

# %%
# !python -m covid-mask-detector.data_preparation
# Out:
# ...
# Unzipping...Done.
# mask photos: 100% 525/525 [00:05<00:00, 95.51it/s]
# non mask photos: 100% 460/460 [04:37<00:00,  1.66it/s]
# saving Dataframe to: covid-mask-detector/data/mask_df.csv

# %%
# !python -m covid-mask-detector.train
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
# !zip -r /content/file.zip /content/covid-mask-detector/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/covid-mask-detector/covid-mask-detector/data/self-built-masked-face-recognition-dataset/AFDB_face_dataset/chenyao/1_0_chenyao_0256.jpg (deflated 3%)
#   adding: content/covid-mask-detector/covid-mask-detector/data/self-built-masked-face-recognition-dataset/AFDB_face_dataset/chenyao/1_0_chenyao_0115.jpg (deflated 2%)
#   adding: content/covid-mask-detector/covid-mask-detector/data/self-built-masked-face-recognition-dataset/AFDB_face_dataset/chenyao/1_0_chenyao_0068.jpg (deflated 3%)
#   adding: content/covid-mask-detector/covid-mask-detector/data/self-built-masked-face-recognition-dataset/AFDB_face_dataset/chenyao/1_0_chenyao_0077.jpg (deflated 3%)
#   adding: content/covid-mask-detector/covid-mask-detector/data/self-built-masked-face-recognition-dataset/AFDB_face_dataset/chenyao/0_0_chenyao_0250.jpg (deflated 2%)
# ...
